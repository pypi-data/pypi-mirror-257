# %%
#!pip install tabula-py
#!pip uninstall camelot
# !pip install "camelot-py[base]"
# Out:
# ...
#   Using cached camelot_py-0.10.1-py3-none-any.whl (40 kB)
# ...
#   Using cached tabulate-0.8.10-py3-none-any.whl (29 kB)
# ...
#   Using cached pdfminer.six-20220524-py3-none-any.whl (5.6 MB)
# ...
#   Using cached PyPDF2-2.3.1-py3-none-any.whl (198 kB)
# ...
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# ...
#   Using cached ghostscript-0.7-py2.py3-none-any.whl (25 kB)
# ...
#   Using cached pdftopng-0.2.3-cp39-cp39-win_amd64.whl (1.5 MB)
# ...
#   Using cached cryptography-37.0.2-cp36-abi3-win_amd64.whl (2.4 MB)
# ...
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 3.4.8
#     Uninstalling cryptography-3.4.8:
#       Successfully uninstalled cryptography-3.4.8
# ...

# %%
import pandas
#import tabula

import camelot
#dfs = tabula.read_pdf("Appendix1_SIunits.pdf",pages="all")
#df = tabula.read_pdf("Appendix1_SIunits.pdf", pages=[42])
df = camelot.read_pdf("Appendix1_SIunits.pdf")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_48844/1007093366.py in <module>
#       5 #dfs = tabula.read_pdf("Appendix1_SIunits.pdf",pages="all")
#       6 #df = tabula.read_pdf("Appendix1_SIunits.pdf", pages=[42])
# ----> 7 df = camelot.read_pdf("Appendix1_SIunits.pdf")
#
# c:\Users\jackm\anaconda3\lib\site-packages\camelot\io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     111         p = PDFHandler(filepath, pages=pages, password=password)
#     112         kwargs = remove_extra(kwargs, flavor=flavor)
# --> 113         tables = p.parse(
#     114             flavor=flavor,
#     115             suppress_stdout=suppress_stdout,
#
# c:\Users\jackm\anaconda3\lib\site-packages\camelot\handlers.py in parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
# ...

# %%
df
# Out:
# [                                           TABLE A–26
#  0   Enthalpy of formation, Gibbs function of forma...
#  1                                         258C, 1 atm
#  2                                               _ _ _
#  3                                       h8 s 8f g 8 f
#  4         Substance Formula kJ/kmol kJ/kmol kJ/kmol·K
#  5                                Carbon C(s) 0 0 5.74
#  6                           Hydrogen H (g) 130.6820 0
#  7                           Nitrogen N (g) 191.6120 0
#  8                             Oxygen O (g) 205.0420 0
#  9      Carbon monoxide CO(g) 2110,530 2137,150 197.65
#  10     Carbon dioxide CO (g) 213.8022393,520 2394,360
#  11        Water vapor H O(g) 188.8322241,820 2228,590
#  12               Water H O(,) 69.9222285,830 2237,180
#  13  Hydrogen peroxide H O (g) 232.632 22136,310 21...
#  14              Ammonia NH (g) 192.333246,190 216,590
#  15              Methane CH (g) 186.164274,850 250,790
# ...

# %%
for i,df in enumerate(dfs):
    print(f'df {i}')
    print(df.head())
# Out:
# df 0
#   Unnamed: 0  Confirming Pages\rAPPENDIX  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0        NaN                         NaN         NaN         NaN         NaN
# 1        NaN                         NaN         NaN         NaN         NaN
# 2        NaN                         NaN         NaN         NaN         NaN
# 3        NaN                         NaN         NaN         NaN         NaN
# 4        NaN                         NaN         NaN         NaN         NaN
#
#    Unnamed: 4  Unnamed: 5
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
# df 1
#    Unnamed: 0  Confirming Pages\rAPPENDIX
# 0         NaN                         NaN
# df 2
#    Unnamed: 0  Confirming Pages\rAPPENDIX
# 0         NaN                         NaN
# df 3
#    Unnamed: 0  Confirming Pages\rAPPENDIX
# 0         NaN                         NaN
# df 4
#    Unnamed: 0  Confirming Pages\rAPPENDIX
# ...

# %%
dfs[55]
# Out:
#                                            TABLE A–26
# 0   Enthalpy of formation, Gibbs function of forma...
# 1                                         258C, 1 atm
# 2                                               _ _ _
# 3                                       h8 s 8f g 8 f
# 4         Substance Formula kJ/kmol kJ/kmol kJ/kmol·K
# 5                                Carbon C(s) 0 0 5.74
# 6                           Hydrogen H (g) 130.6820 0
# 7                           Nitrogen N (g) 191.6120 0
# 8                             Oxygen O (g) 205.0420 0
# 9      Carbon monoxide CO(g) 2110,530 2137,150 197.65
# 10     Carbon dioxide CO (g) 213.8022393,520 2394,360
# 11        Water vapor H O(g) 188.8322241,820 2228,590
# 12               Water H O(,) 69.9222285,830 2237,180
# 13  Hydrogen peroxide H O (g) 232.632 22136,310 21...
# 14              Ammonia NH (g) 192.333246,190 216,590
# 15              Methane CH (g) 186.164274,850 250,790
# ...
