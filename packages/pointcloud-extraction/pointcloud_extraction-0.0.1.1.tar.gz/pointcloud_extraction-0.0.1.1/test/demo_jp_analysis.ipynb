# %% [markdown]
# # Doing Point cloud data extraction and token attribution (Circum tutorial) for the point cloud dataset of noto region of Japan.
#
# This are tutorials for analysing the pointcloud dataset released by the geospatial organisation of Japan for the region of Noto Peninsula before the earthquake.
#
# This will demonstrate our E2E pipeline for the users providing how they can
# - Parse the various tiles from the dataset and get the initial metadata of the pointcloud.
# - Perform the preprocessing steps to get the pointcloud in a format that can be used for further steps processing.
# - After cropping and generating the new lidar file for doing the tiling process (optional).
# - And finally attributing the tokens in for data providers for their contribution to the protocol.

# %%
# installing all the requisite dependencies of the data_preparation project.
# %pip install  -r ../requirements.txt
## installing the dependencies of the protocol.
# !pip install flytekit bacalhau-sdk flytekitplugins-bacalhau 

## for storage clients, we provide the intigeration with IPFS storage using lighthouse or the web3.storage
# !pip install lighthouseweb3

## for the web3 storage:
# !npm install -g @web3-storage/w3-cli 
## then storing the necessary env variables to the bashrc in order to run the w3cli without the need of creating alias.
#!cat WEB3_STORAGE_ENV >> ~/.bashrc
# !w3 space create circum_user_database
# Out:
# Requirement already satisfied: openai in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: open3d in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: geopandas in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (0.14.3)
# Requirement already satisfied: laspy in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 5)) (2.5.3)
# Requirement already satisfied: shapely in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 6)) (2.0.2)
# Requirement already satisfied: pyshp in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 7)) (2.3.1)
# Requirement already satisfied: pycrs in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 8)) (1.0.2)
# Requirement already satisfied: pylas in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 9)) (0.4.3)
# Requirement already satisfied: nerfstudio in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 10)) (1.0.1)
# Requirement already satisfied: pycolmap in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 11)) (0.6.1)
# Requirement already satisfied: opencv-python in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 12)) (4.8.0.76)
# Requirement already satisfied: tyro in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: pytest in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from -r ../requirements.txt (line 14)) (6.2.5)
# Requirement already satisfied: sniffio in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (0.26.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: tqdm>4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (4.66.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from openai->-r ../requirements.txt (line 1)) (2.5.3)
# Requirement already satisfied: werkzeug>=2.2.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.21 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: pillow>=9.3.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (10.2.0)
# Requirement already satisfied: configargparse in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (1.7)
# Requirement already satisfied: pandas>=1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: pyquaternion in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (0.9.9)
# Requirement already satisfied: matplotlib>=3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (3.8.2)
# Requirement already satisfied: numpy>=1.18.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (1.26.3)
# Requirement already satisfied: dash>=2.6.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (2.15.0)
# Requirement already satisfied: pyyaml>=5.4.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: nbformat>=5.7.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (5.9.2)
# Requirement already satisfied: addict in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: ipywidgets>=8.0.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from open3d->-r ../requirements.txt (line 2)) (8.1.1)
# Requirement already satisfied: pyproj>=3.3.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from geopandas->-r ../requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: fiona>=1.8.21 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from geopandas->-r ../requirements.txt (line 3)) (1.9.5)
# Requirement already satisfied: packaging in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from geopandas->-r ../requirements.txt (line 3)) (23.2)
# Requirement already satisfied: jupyterlab>=3.3.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (4.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: rawpy>=0.18.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.19.0)
# Requirement already satisfied: msgpack>=1.0.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (1.0.7)
# Collecting protobuf!=3.20.0,<=3.20.3
#   Using cached protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Requirement already satisfied: imageio>=2.21.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (2.33.1)
# Requirement already satisfied: pymeshlab>=2022.2.post2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (2023.12.post1)
# Requirement already satisfied: plotly>=5.7.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (5.18.0)
# Requirement already satisfied: timm==0.6.7 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.6.7)
# Requirement already satisfied: pathos in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.3.2)
# Requirement already satisfied: viser==0.1.21 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.1.21)
# Requirement already satisfied: mediapy>=1.1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: torchmetrics[image]>=1.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (1.3.0.post0)
# Requirement already satisfied: python-socketio>=5.7.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (5.11.0)
# Requirement already satisfied: rich>=12.5.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (13.7.0)
# Requirement already satisfied: nerfacc==0.5.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.5.2)
# Requirement already satisfied: requests in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (2.31.0)
# Requirement already satisfied: splines==0.3.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.3.0)
# Requirement already satisfied: torchvision>=0.14.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.17.0)
# Requirement already satisfied: tensorboard>=2.13.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (2.15.1)
# Requirement already satisfied: msgpack-numpy>=0.4.8 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.4.8)
# Requirement already satisfied: torch>=1.13.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (2.2.0)
# Requirement already satisfied: nuscenes-devkit>=1.1.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (1.1.9)
# Requirement already satisfied: pytorch-msssim in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: jaxtyping>=0.2.15 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.2.25)
# Requirement already satisfied: appdirs>=1.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (1.4.4)
# Requirement already satisfied: trimesh>=3.20.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (4.1.3)
# Requirement already satisfied: awscli>=1.31.10 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (1.32.34)
# Requirement already satisfied: scikit-image>=0.19.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.22.0)
# Requirement already satisfied: wandb>=0.13.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.16.2)
# Requirement already satisfied: gsplat==0.1.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.1.3)
# Requirement already satisfied: ninja>=1.10 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (1.11.1.1)
# Requirement already satisfied: pyngrok>=5.1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (7.1.0)
# Requirement already satisfied: cryptography>=38 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (41.0.7)
# Requirement already satisfied: av>=9.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (11.0.0)
# Requirement already satisfied: xatlas in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (0.0.8)
# Requirement already satisfied: gdown>=4.6.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (5.1.0)
# Requirement already satisfied: comet-ml>=3.33.8 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nerfstudio->-r ../requirements.txt (line 10)) (3.37.1)
# Requirement already satisfied: nodeenv>=1.8.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from viser==0.1.21->nerfstudio->-r ../requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: scipy>=1.7.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from viser==0.1.21->nerfstudio->-r ../requirements.txt (line 10)) (1.12.0)
# Requirement already satisfied: pyliblzfse>=0.4.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from viser==0.1.21->nerfstudio->-r ../requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: websockets>=10.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from viser==0.1.21->nerfstudio->-r ../requirements.txt (line 10)) (12.0)
# Requirement already satisfied: psutil>=5.9.5 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from viser==0.1.21->nerfstudio->-r ../requirements.txt (line 10)) (5.9.8)
# Requirement already satisfied: yourdfpy>=0.0.53 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from viser==0.1.21->nerfstudio->-r ../requirements.txt (line 10)) (0.0.56)
# Requirement already satisfied: docstring-parser>=0.14.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tyro->-r ../requirements.txt (line 13)) (0.15)
# Requirement already satisfied: shtab>=1.5.6 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tyro->-r ../requirements.txt (line 13)) (1.6.5)
# Requirement already satisfied: attrs>=19.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pytest->-r ../requirements.txt (line 14)) (23.2.0)
# Requirement already satisfied: py>=1.8.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pytest->-r ../requirements.txt (line 14)) (1.11.0)
# Requirement already satisfied: iniconfig in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pytest->-r ../requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pytest->-r ../requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: toml in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pytest->-r ../requirements.txt (line 14)) (0.10.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai->-r ../requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai->-r ../requirements.txt (line 1)) (3.6)
# Collecting botocore==1.34.34
#   Using cached botocore-1.34.34-py3-none-any.whl (11.9 MB)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from awscli>=1.31.10->nerfstudio->-r ../requirements.txt (line 10)) (0.10.0)
# Collecting colorama<0.4.5,>=0.2.5
#   Using cached colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: docutils<0.17,>=0.10 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from awscli>=1.31.10->nerfstudio->-r ../requirements.txt (line 10)) (0.16)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from awscli>=1.31.10->nerfstudio->-r ../requirements.txt (line 10)) (4.7.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from botocore==1.34.34->awscli>=1.31.10->nerfstudio->-r ../requirements.txt (line 10)) (1.0.1)
# Collecting urllib3<2.1,>=1.25.4
#   Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from botocore==1.34.34->awscli>=1.31.10->nerfstudio->-r ../requirements.txt (line 10)) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (0.21.7)
# Requirement already satisfied: six in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (1.40.0)
# Requirement already satisfied: everett[ini]<3.2.0,>=1.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (3.1.0)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (4.21.1)
# Requirement already satisfied: websocket-client<1.4.0,>=0.55.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: semantic-version>=2.8.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: simplejson in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (3.19.2)
# Requirement already satisfied: wurlitzer>=1.0.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: wrapt>=1.11.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: python-box<7.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (6.1.0)
# Requirement already satisfied: cffi>=1.12 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from cryptography>=38->nerfstudio->-r ../requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: importlib-metadata in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (7.0.1)
# Requirement already satisfied: retrying in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (1.3.4)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: nest-asyncio in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: setuptools in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (69.0.3)
# Requirement already satisfied: dash-table==5.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (5.0.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->-r ../requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: click~=8.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->-r ../requirements.txt (line 3)) (8.1.7)
# Requirement already satisfied: certifi in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->-r ../requirements.txt (line 3)) (2023.11.17)
# Requirement already satisfied: cligj>=0.5 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->-r ../requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: filelock in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from gdown>=4.6.0->nerfstudio->-r ../requirements.txt (line 10)) (3.13.1)
# Requirement already satisfied: beautifulsoup4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from gdown>=4.6.0->nerfstudio->-r ../requirements.txt (line 10)) (4.12.3)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 1)) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d->-r ../requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d->-r ../requirements.txt (line 2)) (4.0.9)
# Requirement already satisfied: ipython>=6.1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d->-r ../requirements.txt (line 2)) (8.21.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d->-r ../requirements.txt (line 2)) (5.14.1)
# Requirement already satisfied: comm>=0.1.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d->-r ../requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: typeguard<3,>=2.13.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jaxtyping>=0.2.15->nerfstudio->-r ../requirements.txt (line 10)) (2.13.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (2.12.5)
# Requirement already satisfied: tomli in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (3.1.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (0.2.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (2.2.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.19.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (2.25.2)
# Requirement already satisfied: async-lru>=1.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (2.0.4)
# Requirement already satisfied: jupyter-core in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (5.7.1)
# Requirement already satisfied: ipykernel in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (6.29.0)
# Requirement already satisfied: tornado>=6.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jupyterlab>=3.3.4->nerfstudio->-r ../requirements.txt (line 10)) (6.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from matplotlib>=3->open3d->-r ../requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from matplotlib>=3->open3d->-r ../requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from matplotlib>=3->open3d->-r ../requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from matplotlib>=3->open3d->-r ../requirements.txt (line 2)) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from matplotlib>=3->open3d->-r ../requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: fastjsonschema in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nbformat>=5.7.0->open3d->-r ../requirements.txt (line 2)) (2.19.1)
# Requirement already satisfied: cachetools in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nuscenes-devkit>=1.1.1->nerfstudio->-r ../requirements.txt (line 10)) (5.3.2)
# Requirement already satisfied: pycocotools>=2.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nuscenes-devkit>=1.1.1->nerfstudio->-r ../requirements.txt (line 10)) (2.0.7)
# Requirement already satisfied: fire in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nuscenes-devkit>=1.1.1->nerfstudio->-r ../requirements.txt (line 10)) (0.5.0)
# Requirement already satisfied: descartes in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nuscenes-devkit>=1.1.1->nerfstudio->-r ../requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: jupyter in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nuscenes-devkit>=1.1.1->nerfstudio->-r ../requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pandas>=1.0->open3d->-r ../requirements.txt (line 2)) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from plotly>=5.7.0->nerfstudio->-r ../requirements.txt (line 10)) (8.2.3)
# Requirement already satisfied: pydantic-core==2.14.6 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 1)) (2.14.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: bidict>=0.21.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from python-socketio>=5.7.1->nerfstudio->-r ../requirements.txt (line 10)) (0.22.1)
# Requirement already satisfied: python-engineio>=4.8.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from python-socketio>=5.7.1->nerfstudio->-r ../requirements.txt (line 10)) (4.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from requests->nerfstudio->-r ../requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from rich>=12.5.1->nerfstudio->-r ../requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from rich>=12.5.1->nerfstudio->-r ../requirements.txt (line 10)) (2.17.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from scikit-image>=0.19.3->nerfstudio->-r ../requirements.txt (line 10)) (2024.1.30)
# Requirement already satisfied: lazy_loader>=0.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from scikit-image>=0.19.3->nerfstudio->-r ../requirements.txt (line 10)) (0.3)
# Requirement already satisfied: networkx>=2.8 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from scikit-image>=0.19.3->nerfstudio->-r ../requirements.txt (line 10)) (3.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d->-r ../requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d->-r ../requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tensorboard>=2.13.0->nerfstudio->-r ../requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: absl-py>=0.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tensorboard>=2.13.0->nerfstudio->-r ../requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tensorboard>=2.13.0->nerfstudio->-r ../requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tensorboard>=2.13.0->nerfstudio->-r ../requirements.txt (line 10)) (3.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tensorboard>=2.13.0->nerfstudio->-r ../requirements.txt (line 10)) (2.27.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tensorboard>=2.13.0->nerfstudio->-r ../requirements.txt (line 10)) (1.60.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (11.0.2.54)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (8.9.2.26)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (12.1.0.106)
# Requirement already satisfied: sympy in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (1.12)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (2.2.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (10.3.2.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (2.19.3)
# Requirement already satisfied: fsspec in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (2023.12.2)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (12.1.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.1->nerfstudio->-r ../requirements.txt (line 10)) (12.3.101)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torchmetrics[image]>=1.0.1->nerfstudio->-r ../requirements.txt (line 10)) (0.10.1)
# Requirement already satisfied: torch-fidelity<=0.4.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from torchmetrics[image]>=1.0.1->nerfstudio->-r ../requirements.txt (line 10)) (0.3.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from wandb>=0.13.3->nerfstudio->-r ../requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from wandb>=0.13.3->nerfstudio->-r ../requirements.txt (line 10)) (3.1.41)
# Requirement already satisfied: setproctitle in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from wandb>=0.13.3->nerfstudio->-r ../requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from werkzeug>=2.2.3->open3d->-r ../requirements.txt (line 2)) (2.1.4)
# Requirement already satisfied: multiprocess>=0.70.16 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pathos->nerfstudio->-r ../requirements.txt (line 10)) (0.70.16)
# Requirement already satisfied: ppft>=1.7.6.8 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pathos->nerfstudio->-r ../requirements.txt (line 10)) (1.7.6.8)
# Requirement already satisfied: dill>=0.3.8 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pathos->nerfstudio->-r ../requirements.txt (line 10)) (0.3.8)
# Requirement already satisfied: pox>=0.3.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pathos->nerfstudio->-r ../requirements.txt (line 10)) (0.3.4)
# Requirement already satisfied: pycparser in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=38->nerfstudio->-r ../requirements.txt (line 10)) (2.21)
# Requirement already satisfied: configobj in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml>=3.33.8->nerfstudio->-r ../requirements.txt (line 10)) (5.0.8)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d->-r ../requirements.txt (line 2)) (1.7.0)
# ...
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from s3fs>=0.6.0->flytekit) (2.11.1)
# Collecting colorama>=0.4.6
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: chardet>=5.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tox<5.0.0,>=4.2.6->bacalhau-sdk) (5.2.0)
# Requirement already satisfied: pyproject-api>=1.6.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tox<5.0.0,>=4.2.6->bacalhau-sdk) (1.6.1)
# Requirement already satisfied: filelock>=3.13.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tox<5.0.0,>=4.2.6->bacalhau-sdk) (3.13.1)
# Requirement already satisfied: pluggy>=1.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tox<5.0.0,>=4.2.6->bacalhau-sdk) (1.4.0)
# Requirement already satisfied: cachetools>=5.3.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from tox<5.0.0,>=4.2.6->bacalhau-sdk) (5.3.2)
# Requirement already satisfied: readme-renderer>=35.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from twine<5.0.0,>=4.0.2->bacalhau-sdk) (42.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from twine<5.0.0,>=4.0.2->bacalhau-sdk) (1.0.0)
# Requirement already satisfied: rfc3986>=1.4.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from twine<5.0.0,>=4.0.2->bacalhau-sdk) (2.0.0)
# Requirement already satisfied: pkginfo>=1.8.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from twine<5.0.0,>=4.0.2->bacalhau-sdk) (1.9.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from rich->flytekit) (3.0.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from virtualenv<21.0.0,>=20.2.2->bacalhau-sdk) (0.3.8)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.46 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from adlfs->flytekit) (0.0.53)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from adlfs->flytekit) (1.29.7)
# Requirement already satisfied: azure-storage-blob>=12.12.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from adlfs->flytekit) (12.19.0)
# Requirement already satisfied: azure-identity in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from adlfs->flytekit) (1.15.0)
# Requirement already satisfied: decorator>4.1.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from gcsfs->flytekit) (5.1.1)
# Requirement already satisfied: google-auth-oauthlib in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from gcsfs->flytekit) (1.2.0)
# Requirement already satisfied: google-cloud-storage in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from gcsfs->flytekit) (2.14.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from gitpython->flytekit) (4.0.11)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=0.6.0->flytekit) (0.11.0)
# Collecting botocore<1.34.28,>=1.33.2
#   Using cached botocore-1.34.27-py3-none-any.whl (11.9 MB)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.6.0->flytekit) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.6.0->flytekit) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.6.0->flytekit) (1.4.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.6.0->flytekit) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.6.0->flytekit) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.6.0->flytekit) (23.2.0)
# Requirement already satisfied: msal<2,>=1.16.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from azure-datalake-store<0.1,>=0.0.46->adlfs->flytekit) (1.26.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from azure-storage-blob>=12.12.0->adlfs->flytekit) (0.6.1)
# Requirement already satisfied: pycparser in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from cffi>=1.12->cryptography<42.0.0,>=39.0.1->bacalhau-sdk) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython->flytekit) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=12.0.1->flytekit) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=12.0.1->flytekit) (4.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter>=1.7.3->flytekit) (2.1.4)
# Requirement already satisfied: mdurl~=0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->flytekit) (0.1.2)
# Requirement already satisfied: setuptools in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from nodeenv>=0.11.1->pre-commit<3.0.0,>=2.12.0->bacalhau-sdk) (69.0.3)
# Requirement already satisfied: text-unidecode>=1.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from python-slugify>=4.0.0->cookiecutter>=1.7.3->flytekit) (1.3)
# Requirement already satisfied: docutils>=0.13.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from readme-renderer>=35.0->twine<5.0.0,>=4.0.2->bacalhau-sdk) (0.16)
# Requirement already satisfied: nh3>=0.2.14 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from readme-renderer>=35.0->twine<5.0.0,>=4.0.2->bacalhau-sdk) (0.2.15)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from arrow->cookiecutter>=1.7.3->flytekit) (2.8.19.20240106)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from azure-identity->adlfs->flytekit) (1.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from google-cloud-storage->gcsfs->flytekit) (2.16.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from google-cloud-storage->gcsfs->flytekit) (1.5.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from google-cloud-storage->gcsfs->flytekit) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from google-cloud-storage->gcsfs->flytekit) (2.7.0)
# Requirement already satisfied: more-itertools in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from jaraco.classes->keyring>=18.0.1->flytekit) (10.2.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from botocore<1.34.28,>=1.33.2->aiobotocore<3.0.0,>=2.5.4->s3fs>=0.6.0->flytekit) (1.0.1)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.46->adlfs->flytekit) (2.8.0)
# Requirement already satisfied: portalocker<3,>=1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity->adlfs->flytekit) (2.8.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=12.0.1->flytekit) (0.5.1)
# Installing collected packages: urllib3, pygments, protobuf, colorama, certifi, black, botocore
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.17.2
#     Uninstalling Pygments-2.17.2:
#       Successfully uninstalled Pygments-2.17.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.4
#     Uninstalling colorama-0.4.4:
#       Successfully uninstalled colorama-0.4.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
#   Attempting uninstall: black
#     Found existing installation: black 24.1.1
#     Uninstalling black-24.1.1:
#       Successfully uninstalled black-24.1.1
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.34
#     Uninstalling botocore-1.34.34:
#       Successfully uninstalled botocore-1.34.34
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.15.1 requires protobuf<4.24,>=3.19.6, but you have protobuf 4.25.2 which is incompatible.
# nerfstudio 1.0.1 requires protobuf!=3.20.0,<=3.20.3, but you have protobuf 4.25.2 which is incompatible.
# eth-brownie 1.20.0 requires black==24.1.1, but you have black 22.12.0 which is incompatible.
# eth-brownie 1.20.0 requires certifi==2023.11.17, but you have certifi 2023.7.22 which is incompatible.
# eth-brownie 1.20.0 requires pygments==2.17.2, but you have pygments 2.15.0 which is incompatible.
# eth-brownie 1.20.0 requires urllib3==2.2.0, but you have urllib3 1.26.18 which is incompatible.
# eth-ape 0.7.7 requires eth-abi<5,>=4.2.1, but you have eth-abi 5.0.0 which is incompatible.
# eth-ape 0.7.7 requires urllib3<3,>=2.0.0, but you have urllib3 1.26.18 which is incompatible.
# awscli 1.32.34 requires botocore==1.34.34, but you have botocore 1.34.27 which is incompatible.
# awscli 1.32.34 requires colorama<0.4.5,>=0.2.5, but you have colorama 0.4.6 which is incompatible.
# Successfully installed black-22.12.0 botocore-1.34.27 certifi-2023.7.22 colorama-0.4.6 protobuf-4.25.2 pygments-2.15.0 urllib3-1.26.18
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: lighthouseweb3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (0.1.4)
# Requirement already satisfied: requests in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from lighthouseweb3) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from requests->lighthouseweb3) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from requests->lighthouseweb3) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from requests->lighthouseweb3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from requests->lighthouseweb3) (3.6)
# WARNING: There was an error checking the latest version of pip.
# npm ERR! code E404midealTree buildDepseps
# npm ERR! 404 Not Found - GET https://registry.npmjs.org/@web3-storage%2fw3-cli - Not found
# npm ERR! 404
# npm ERR! 404  '@web3-storage/w3-cli@*' is not in this registry.
# npm ERR! 404
# npm ERR! 404 Note that you can also install from a
# npm ERR! 404 tarball, folder, http url, or git url.
#
# npm ERR! A complete log of this run can be found in: /home/ubuntu/.npm/_logs/2024-02-07T14_22_54_105Z-debug-0.log
# /bin/bash: w3: command not found

# %%
import laspy
import numpy as np
import pandas as pd
import os
from subprocess import call
params_list = []

## downloading the 

def read_data_header(base_dir = '../datas/'):
    ## downloading the dataset
    if not os.path.exists(base_dir):
        call(["wget", "https://gic-ishikawa.s3.ap-northeast-1.amazonaws.com/2024/noto/las/notoeast1.zip", "-O", "japan_ne.zip"])
        call(["7z",  "-x" , "japan_ne.zip"])
        call(["rm", "japan_ne.zip"])
    
    for it in os.listdir(base_dir):
        try:
            file_path = os.path.join(base_dir, it)
            read_file = laspy.read(file_path)
            dimensions = (str(read_file.header.x_max), str(read_file.header.x_min) ,str(read_file.header.y_max) ,str(read_file.header.y_min), str(read_file.header.z_max) ,str(read_file.header.z_min) )
            point_amount = (str(read_file.header.point_count))
            maxs_mins = (str(read_file.header.maxs), str(read_file.header.mins))
            scale = (str(read_file.header.scale[0]))
            point_dimensions = (read_file.point_format.dimensions)  
            #user_data = read_file['user_data']          
            
            params_list.append({
            "filename": it,
            "dimensions": dimensions,
            "point_amount": point_amount,
            "maxs_mins": maxs_mins,
            "scale": scale,
            "point_dimensions": point_dimensions,
            })    
            
            # print('dimensions' + ' ' + str(read_file.header.x_max) + ' ' + str(read_file.header.x_min) + ' ' + str(read_file.header.y_max) + ' ' + str(read_file.header.y_min))
            # print('number of points' + ' ' + str(read_file.header.point_count))
            # print('header maxs and mins ' + '...' + str(read_file.header.maxs) + '...' + str(read_file.header.mins))
            # print('scale:' + str(read_file.header.scale[0]))
            # print('offset:' + str(read_file.header.offset[0]))
            # print('crs code:' + str(read_file))
            # print ('dimensions:' + str(read_file.point_format.dimensions))
        except Exception as e:
            print( f"error in getting values for file {it}: " +str(e))
    df = pd.DataFrame(params_list)
    return df
    
print(read_data_header())
# Out:
# error in getting values for file 07ED5834.las: buffer size must be a multiple of element size
# error in getting values for file japan_ne.zip: Invalid file signature "b'PK\x03\x04'"
# error in getting values for file bunny.pcd: Invalid file signature "b'# .P'"
#         filename                                         dimensions  \
# 0   07ED4942.las  (-0.01, -1000.0, 166499.99, 165750.0, 242.1400...
# 1   07ED5814.las  (-6000.01, -7000.0, 164249.99, 163500.0, 197.6...
# 2   07ED4933.las  (-3000.01, -4000.0, 165749.99, 165000.0, 183.0...
# 3   07ED5821.las  (-5000.01, -6000.0, 164999.99, 164250.0, 123.2...
# 4   07ED4844.las  (-4000.01, -5000.0, 165749.99, 165000.0, 91.42...
# 5   07ED5824.las  (-4000.01, -5000.0, 164249.99, 163500.0, 329.9...
# 6   07ED5822.las  (-4000.01, -5000.0, 164999.99, 164250.0, 254.1...
# 7   07ED4934.las  (-2000.01, -3000.0, 165749.99, 165000.0, 274.5...
# 8   07ED5832.las  (-6000.01, -7000.0, 163499.99, 162750.0, 262.3...
# 9   07ED5831.las  (-7000.01, -8000.0, 163499.99, 162750.0, 49.96...
# 10  07ED5823.las  (-5000.01, -6000.0, 164249.99, 163500.0, 246.3...
# 11  07ED5833.las  (-7000.01, -8000.0, 162749.99, 162000.0, 261.5...
# 12  07ED4943.las  (-1000.01, -2000.0, 165749.99, 165000.0, 273.8...
# 13  07ED4932.las  (-2000.01, -3000.0, 166499.99, 165750.0, 185.1...
# 14  07ED4944.las  (-0.01, -1000.0, 165749.99, 165000.0, 249.86, ...
# 15  07ED4941.las  (-1000.01, -2000.0, 166499.99, 165750.0, 221.3...
# 16  07ED4924.las  (-0.01, -1000.0, 167249.99, 166500.0, 109.73, ...
#
#    point_amount                                          maxs_mins  scale  \
# 0      18136802  ([-1.0000000e-02  1.6649999e+05  2.4214000e+02...  0.001
# 1       6359273  ([ -6000.01 164249.99    197.64], [-7.000e+03 ...  0.001
# 2      15392307  ([ -3000.01 165749.99    183.07], [-4.00e+03  ...   0.01
# 3       3327400  ([-5.0000100e+03  1.6499999e+05  1.2324000e+02...  0.001
# 4       2535148  ([-4.0000100e+03  1.6574999e+05  9.1420000e+01...   0.01
# 5      22866700  ([ -4000.01 164249.99    329.97], [-5.000e+03 ...   0.01
# 6      17083712  ([ -4000.01 164999.99    254.14], [ -5000. 164...   0.01
# 7      22308909  ([ -2000.01 165749.99    274.59], [-3.00e+03  ...  0.001
# 8      14595005  ([ -6000.01 163499.99    262.33], [-7.0000e+03...  0.001
# 9       1096053  ([-7.0000100e+03  1.6349999e+05  4.9960000e+01...  0.001
# 10     17169376  ([ -5000.01 164249.99    246.34], [-6.000e+03 ...  0.001
# 11      9275743  ([ -7000.01 162749.99    261.53], [-8.00e+03  ...  0.001
# 12     19711367  ([ -1000.01 165749.99    273.87], [-2.000e+03 ...  0.001
# 13      6038623  ([ -2000.01 166499.99    185.16], [-3.0000e+03...  0.001
# 14     17864031  ([-1.0000000e-02  1.6574999e+05  2.4986000e+02...  0.001
# 15     12582210  ([ -1000.01 166499.99    221.35], [-2.0000e+03...  0.001
# 16      2783359  ([-1.0000000e-02  1.6724999e+05  1.0973000e+02...  0.001
#
#                                      point_dimensions
# 0   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 1   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 2   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 3   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 4   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 5   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 6   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 7   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 8   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 9   [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 10  [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 11  [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 12  [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 13  [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 14  [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 15  [(X, DimensionKind.SignedInteger, 32, 1, True,...
# 16  [(X, DimensionKind.SignedInteger, 32, 1, True,...

# %%
## functions for operating on las file.
 
def parameters_header(lidar_file_path = "../datas/07ED4844.las"):
    """
    This function reads the las file header and returns the parameters as a dictionary
    """
    params = []
    with laspy.open(lidar_file_path) as fh:
        print(f"file details: major-version: {fh.header.major_version}")
        params = {
            
                "x_min" : fh.header.x_min,
                "x_max" : fh.header.x_max,
                "x_scale" : fh.header.x_scale,
                "x_offset" : fh.header.x_offset,
                "y_min" : fh.header.y_min,
                "y_max" : fh.header.y_max,
                "y_scale" : fh.header.y_scale,
                "y_offset" : fh.header.y_offset,
                "z_min" : fh.header.z_min,
                "z_max" : fh.header.z_max,
                "z_scale" : fh.header.z_scale,
                "z_offset" : fh.header.z_offset,
            }
        
        return pd.DataFrame(params, index=[0])

df_init = parameters_header()

print("-----------------------------------------------------")
print(f"scaling values:  {df_init['x_scale'][0], df_init['y_scale'][0], df_init['z_scale'][0]}")
def scaling_parameters(x,y,z, df_init):
    """
    fetches all the sides of the X,Y,Z axis and returns them as a dictionary
    """    
     
    #if (x + df_init['x_scale'][0]) > df_init['']     
    X_coord = (x * df_init['x_scale'][0]) + df_init['x_offset'][0],
    Z_coord = (z * df_init["z_scale"][0]) + df_init["z_offset"][0],
    Y_coord= (y * df_init["y_scale"][0]) + df_init["y_offset"][0],
    return X_coord,Y_coord,Z_coord


def determine_correct_indices(lidar_file_path):
    """
    defines the indices that are not valid for the point cloud.
    """
    with laspy.open(lidar_file_path) as read_file:
        ## define the current in-valid values for the parameters:
        X_invalid = (read_file.header.mins[0] > abs(df_init['x_max'][0])) | (read_file.header.maxs[0] < df_init['x_min'][0])
        Y_invalid = (read_file.header.mins[1] > abs(df_init['y_max'][0])) | (read_file.header.maxs[1] < df_init['y_min'][0])
        Z_invalid = (read_file.header.mins[2] > abs(df_init['z_max'][0])) | (read_file.header.maxs[2] < df_init['z_min'][0])
        bad_indices = np.where(X_invalid | Y_invalid | Z_invalid)

    print(bad_indices)


print("example of scaling of the coordinates: " + str(scaling_parameters(35.447227, 136.756165,100, df_init)))
# Out:
# file details: major-version: 1
# -----------------------------------------------------
# scaling values:  (0.01, 0.01, 0.01)
# example of scaling of the coordinates: ((0.35447227,), (1.36756165,), (1.0,))

# %% [markdown]
# ## Now running the cropping step:

# %%
import open3d as o3d
import geopandas as gpd
from shapely.geometry import Point  
from pyproj import Transformer
import sys
from geopandas import GeoDataFrame, points_from_xy
sys.path.append("../../../")
from data_preparation.llm.pipeline_generation import  PDAL_template_manual
from subprocess import  check_call

Points1 = Point(float(37.124), float(136.54), float(1.0))
Points2 = Point(float(38.124), float(137.54), float(1.0))
transformer = Transformer.from_crs('EPSG:4326','EPSG:6685') ## for GPS coordiantes to japan coordinates
lidar_file_path = "../datas/07ED4844.las"

## taking exampl of the points that are considered as boundation points 
X1,Y1,Z1 = transformer.transform(Points1.x, Points1.y, Points1.z)
X2,Y2,Z2 = transformer.transform(Points2.x, Points2.y, Points2.z)

## scaling to thelocal coordinates
X1_scaled, Y1_scaled, Z1_scaled = scaling_parameters(X1,Y1,Z1,df_init)
X2_scaled, Y2_scaled, Z2_scaled = scaling_parameters(X2,Y2,Z2,df_init)


buffer_radius = 0.3

print(f"finally scaled params: X_Scaled: {X1_scaled} to {X2_scaled}, Y_scaled:  {Y1_scaled} to {Y2_scaled} , Z_scaled: {Z1_scaled} to {Z2_scaled} ")
print("so now applying the cropping technique  using PDAL")
fileInfo = laspy.read(lidar_file_path)


# async def pdal_pipeline_processing(filepath, point_x, point_y, point_z, buffer_radius, final_laz_file):
#     try:
#         open_ai = PDAL_json_generation_template()
#         open_ai.define_assistant_parameter("pdal_generator", "transform_cropping.json")
#         await open_ai.creating_message_thread(f"i want you to create a json file (named transform_cropping.json) that converts the given laz file stored in {filepath} by cropping the section with center as {Point(point_x,point_y,point_z)} and radius of {buffer_radius}, having the final transformed filename as {final_laz_file}")
#         print("the application is finally generated: " + os.path.join('.', "transform_cropping.json"))
#         assert os.path.isfile("transform_cropping.json") is True
#         check_call(["pdal", "pipeline", "transform_cropping.json"])
#         assert os.path.isfile("cropped.laz") is True
#     except Exception as e:
#         print("under the pdal_pipeline_processing, the following error:  " + str(e))
    

def generate_crop_pipeline():
    manual_template = PDAL_template_manual()
    lidar_file_path = "../datas/07ED4844.las"
    points = "POINT({}{}{})".format(X1_scaled,Y1_scaled,Z1_scaled)
    manual_template.generate_cropping_template(lidar_file_path,points,10,"demo_crop.json")
    
        




if __name__ == "__main__":
    #await pdal_pipeline_processing(lidar_file_path, X1_scaled, Y1_scaled, Z1_scaled, buffer_radius, "cropped.laz")
    generate_crop_pipeline()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 8
#       6 from geopandas import GeoDataFrame, points_from_xy
#       7 sys.path.append("../../../")
# ----> 8 from data_preparation.llm.pipeline_generation import  PDAL_template_manual
#       9 from subprocess import  check_call
#      11 Points1 = Point(float(37.124), float(136.54), float(1.0))
#
# ImportError: cannot import name 'PDAL_template_manual' from 'data_preparation.llm.pipeline_generation' (/home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/data_preparation/test/../../data_preparation/llm/pipeline_generation.py)

# %% [markdown]
# ## Now comes the reconstruction step(optional) :
#
# In the gepspatial pipeline, we rarely get a well defined pointcloud from the start. thus the pointcloud needs to be reconstructed using the reconstruction algorithms. below we will be giving an example of the how we run the decentralised compute over data platform in order to schedule the reconstruction of the pointcloud. this process at this instance will be simulated on the top of bacalhau public network where the nodes are managed on no cost by the parent company expanso, but in the circum protocol we will be providing the custom network of nodes based on the requirements of the user regarding the nodes, they will be able too bid for the compute job along with the description of the

# %%
from flytekit import workflow, task, dynamic, kwtypes
from bacalhau_apiclient.models import Spec, JobSpecDocker, publisher_spec
from flytekitplugins.bacalhau import BacalhauTask
from subprocess import check_call
from dataclasses import dataclass
from pathlib import Path
from lighthouseweb3 import Lighthouse
bacalhau_reconstruction_job = BacalhauTask(
    name='running surface_reconstruction_job',
    inputs=kwtypes(
        spec=dict,
        api_version=str
    ),
)


store_result = BacalhauTask(
    name='store_ipfs_result',
    inputs=kwtypes(
        spec=dict,
        api_version=str
    ),
)

@dataclass
class reconstructionDatasetFile():
    def __init__(self, toy_example, group, filename, scene_type):
        self.group = group
        self.filename = filename
        self.scene_type = scene_type

@task
def surface_reconstruction_job(input_params_job: reconstructionDatasetFile) -> str:
    
    
    try:
        task_1 = bacalhau_reconstruction_job(
            api_version = "v0.1",
            spec = dict(
                engine="Docker",
                verifier="Noop",
                publisher_spec= {"type": "IPFS"},
                docker= JobSpecDocker(
                    image="devextralabs/neuralangelo:0.1",
                    entrypoint=[input_params_job.filename, input_params_job.scene_type, input_params_job.group],
                ),
                language= {
                    "job_context": None,
                },
                wasm=None,
                resources=None,
                outputs=[
                    {
                        "storage_source": "IPFS",
                        "name": "outputs",
                        "path": "/outputs",
                    }
                ],
                deal={"concurrrrency":1},
            )
        )   
    except Exception as e:
        print("under the surface_reconstruction_job task, the error is: ", e)

    
    cid = task_1
    path = Path(os.path.join(os.getcwd(), "/ipfs/", cid))
    lh = Lighthouse(token=os.environ.get("WEB3STORAGE_TOKEN"))
    print("uploading the file to the ipfs storage")
    print(lh.upload(path))    
    ## here we use the lighthouse storage sdk , but for the web3storage we can also integrate following the tutorials as defined here: https://web3.storage/docs/quickstart/
# Out:
# executing BacalhauTask with name: running surface_reconstruction_job
# executing BacalhauTask with name: store_ipfs_result
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 33
#      29         self.filename = filename
#      30         self.scene_type = scene_type
#      32 @task
# ---> 33 def surface_reconstruction_job(input_params_job: reconstructionDatasetFile) -> str:
#      36     try:
#      37         task_1 = bacalhau_reconstruction_job(
#      38             api_version = "v0.1",
#      39             spec = Spec(
#    (...)
#      60             )
#      61         )
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/task.py:280, in task(_task_function, task_config, cache, cache_serialize, cache_version, retries, interruptible, deprecated, timeout, container_image, environment, requests, limits, secret_requests, execution_mode, task_resolver, docs, disable_deck, pod_template, pod_template_name)
#     277     return task_instance
#     279 if _task_function:
# --> 280     return wrapper(_task_function)
#     281 else:
#     282     return wrapper
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/task.py:260, in task.<locals>.wrapper(fn)
#     249 def wrapper(fn: Callable[..., Any]) -> PythonFunctionTask[T]:
#     250     _metadata = TaskMetadata(
#     251         cache=cache,
#     252         cache_serialize=cache_serialize,
#    (...)
#     257         timeout=timeout,
#     258     )
# --> 260     task_instance = TaskPlugins.find_pythontask_plugin(type(task_config))(
#     261         task_config,
#     262         fn,
#     263         metadata=_metadata,
#     264         container_image=container_image,
#     265         environment=environment,
#     266         requests=requests,
#     267         limits=limits,
#     268         secret_requests=secret_requests,
#     269         execution_mode=execution_mode,
#     270         task_resolver=task_resolver,
#     271         disable_deck=disable_deck,
#     272         docs=docs,
#     273         pod_template=pod_template,
#     274         pod_template_name=pod_template_name,
#     275     )
#     276     update_wrapper(task_instance, fn)
#     277     return task_instance
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/tracker.py:35, in InstanceTrackingMeta.__call__(cls, *args, **kwargs)
#      34 def __call__(cls, *args, **kwargs):
# ---> 35     o = super(InstanceTrackingMeta, cls).__call__(*args, **kwargs)
#      36     o._instantiated_in = InstanceTrackingMeta._find_instance_module()
#      37     return o
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/python_function_task.py:121, in PythonFunctionTask.__init__(self, task_config, task_function, task_type, ignore_input_vars, execution_mode, task_resolver, **kwargs)
#     119 mutated_interface = self._native_interface.remove_inputs(ignore_input_vars)
#     120 name, _, _, _ = extract_task_module(task_function)
# --> 121 super().__init__(
#     122     task_type=task_type,
#     123     name=name,
#     124     interface=mutated_interface,
#     125     task_config=task_config,
#     126     task_resolver=task_resolver,
#     127     **kwargs,
#     128 )
#     130 if self._task_resolver is default_task_resolver:
#     131     # The default task resolver can't handle nested functions
#     132     # TODO: Consider moving this to a can_handle function or something inside the resolver itself.
#     133     if (
#     134         not istestfunction(func=task_function)
#     135         and isnested(func=task_function)
#     136         and not is_functools_wrapped_module_level(task_function)
#     137     ):
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/python_auto_container.py:85, in PythonAutoContainerTask.__init__(self, name, task_config, task_type, container_image, requests, limits, environment, task_resolver, secret_requests, pod_template, pod_template_name, **kwargs)
#      82 kwargs["metadata"] = kwargs["metadata"] if "metadata" in kwargs else TaskMetadata()
#      83 kwargs["metadata"].pod_template_name = pod_template_name
# ---> 85 super().__init__(
#      86     task_type=task_type,
#      87     name=name,
#      88     task_config=task_config,
#      89     security_ctx=sec_ctx,
#      90     **kwargs,
#      91 )
#      92 self._container_image = container_image
#      93 # TODO(katrogan): Implement resource overrides
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/base_task.py:420, in PythonTask.__init__(self, task_type, name, task_config, interface, environment, disable_deck, **kwargs)
#     394 def __init__(
#     395     self,
#     396     task_type: str,
#    (...)
#     402     **kwargs,
#     403 ):
#     404     """
#     405     Args:
#     406         task_type (str): defines a unique task-type for every new extension. If a backend plugin is required then
#    (...)
#     415         disable_deck (bool): If true, this task will not output deck html file
#     416     """
#     417     super().__init__(
#     418         task_type=task_type,
#     419         name=name,
# --> 420         interface=transform_interface_to_typed_interface(interface),
#     421         **kwargs,
#     422     )
#     423     self._python_interface = interface if interface else Interface()
#     424     self._environment = environment if environment else {}
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/interface.py:247, in transform_interface_to_typed_interface(interface)
#     242     input_descriptions = interface.docstring.input_descriptions
#     243     output_descriptions = remap_shared_output_descriptions(
#     244         interface.docstring.output_descriptions, interface.outputs
#     245     )
# --> 247 inputs_map = transform_variable_map(interface.inputs, input_descriptions)
#     248 outputs_map = transform_variable_map(interface.outputs, output_descriptions)
#     249 return _interface_models.TypedInterface(inputs_map, outputs_map)
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/interface.py:345, in transform_variable_map(variable_map, descriptions)
#     343 if variable_map:
#     344     for k, v in variable_map.items():
# --> 345         res[k] = transform_type(v, descriptions.get(k, k))
#     346 return res
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/interface.py:350, in transform_type(x, description)
#     349 def transform_type(x: type, description: Optional[str] = None) -> _interface_models.Variable:
# --> 350     return _interface_models.Variable(type=TypeEngine.to_literal_type(x), description=description)
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/type_engine.py:827, in TypeEngine.to_literal_type(cls, python_type)
#     823 """
#     824 Converts a python type into a flyte specific ``LiteralType``
#     825 """
#     826 transformer = cls.get_transformer(python_type)
# --> 827 res = transformer.get_literal_type(python_type)
#     828 data = None
#     829 if is_annotated(python_type):
#
# File ~/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages/flytekit/core/type_engine.py:320, in DataclassTransformer.get_literal_type(self, t)
#     314     raise ValueError(
#     315         "Flytekit does not currently have support for FlyteAnnotations applied to Dataclass."
#     316         f"Type {t} cannot be parsed."
#     317     )
#     319 if not issubclass(t, DataClassJsonMixin):
# --> 320     raise AssertionError(
#     321         f"Dataclass {t} should be decorated with @dataclass_json to be " f"serialized correctly"
#     322     )
#     323 schema = None
#     324 try:
#
# AssertionError: Dataclass <class '__main__.reconstructionDatasetFile'> should be decorated with @dataclass_json to be serialized correctly

# %% [markdown]
# ## Now comes the stage for onchain disbursement of rewards:
# - we will be deploying and issuing reward token to the users based on the amount of stake that is provided to the other participants.
# - once we get the CID of the rendered dataset, then the token holders can select the amount of the tokens they can stake to the given dataset

# %%
# !pip install eth-brownie
# Out:
# Collecting eth-brownie
#   Downloading eth_brownie-1.20.0-py3-none-any.whl (218 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.7/218.7 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: eth-rlp==1.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (1.0.1)
# Collecting pytest==6.2.5
#   Downloading pytest-6.2.5-py3-none-any.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.7/280.7 kB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth==0.2.13 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.2.13)
# Collecting vvm==0.1.0
#   Downloading vvm-0.1.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: websockets==12.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (12.0)
# Collecting web3==6.15.0
#   Downloading web3-6.15.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 36.8 MB/s eta 0:00:00:00:01
# Requirement already satisfied: rpds-py==0.17.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.17.1)
# Requirement already satisfied: pyyaml==6.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (6.0.1)
# Requirement already satisfied: lru-dict==1.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (1.2.0)
# Collecting pygments==2.17.2
#   Using cached pygments-2.17.2-py3-none-any.whl (1.2 MB)
# Requirement already satisfied: attrs==23.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (23.2.0)
# Requirement already satisfied: eip712==0.2.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.2.4)
# Requirement already satisfied: importlib-metadata==7.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (7.0.1)
# Requirement already satisfied: pycryptodome==3.20.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (3.20.0)
# Collecting multidict==6.0.5
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 14.6 MB/s eta 0:00:00
# Collecting eth-event==1.2.5
#   Downloading eth_event-1.2.5-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: iniconfig==2.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2.0.0)
# Requirement already satisfied: packaging==23.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (23.2)
# Requirement already satisfied: async-timeout==4.0.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (4.0.3)
# Collecting lazy-object-proxy==1.10.0
#   Downloading lazy_object_proxy-1.10.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 kB 10.0 MB/s eta 0:00:00
# Collecting cbor2==5.6.1
#   Downloading cbor2-5.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.0/242.0 kB 34.0 MB/s eta 0:00:00
# Collecting hypothesis==6.27.3
#   Downloading hypothesis-6.27.3-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.6/384.6 kB 43.3 MB/s eta 0:00:00
# Requirement already satisfied: click==8.1.7 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (8.1.7)
# Collecting py-solc-x==1.1.1
#   Downloading py_solc_x-1.1.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: prompt-toolkit==3.0.43 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (3.0.43)
# Collecting certifi==2023.11.17
#   Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Requirement already satisfied: wheel==0.42.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.42.0)
# Requirement already satisfied: regex==2023.12.25 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2023.12.25)
# Requirement already satisfied: bitarray==2.9.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2.9.2)
# Requirement already satisfied: jsonschema==4.21.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (4.21.1)
# Collecting pytest-forked==1.6.0
#   Downloading pytest_forked-1.6.0-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: semantic-version==2.10.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2.10.0)
# Requirement already satisfied: wrapt==1.16.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (1.16.0)
# Requirement already satisfied: eth-account==0.10.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.10.0)
# Requirement already satisfied: eth-utils==2.3.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2.3.1)
# Requirement already satisfied: eth-typing==3.5.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (3.5.2)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2023.12.1)
# Collecting pygments-lexer-solidity==0.7.0
#   Downloading pygments-lexer-solidity-0.7.0.tar.gz (7.3 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: urllib3==2.2.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2.2.0)
# Requirement already satisfied: pyunormalize==15.1.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (15.1.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (3.3.2)
# Requirement already satisfied: hexbytes==0.3.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.3.1)
# Collecting py==1.11.0
#   Using cached py-1.11.0-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: tqdm==4.66.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (4.66.1)
# Requirement already satisfied: pathspec==0.12.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.12.1)
# Requirement already satisfied: aiohttp==3.9.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (3.9.3)
# Collecting rlp==4.0.0
#   Using cached rlp-4.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: parsimonious==0.9.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.9.0)
# Requirement already satisfied: eth-keyfile==0.7.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.7.0)
# Requirement already satisfied: protobuf==4.25.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (4.25.2)
# Requirement already satisfied: toml==0.10.2 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.10.2)
# Requirement already satisfied: sortedcontainers==2.4.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2.4.0)
# Requirement already satisfied: idna==3.6 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (3.6)
# Requirement already satisfied: mypy-extensions==1.0.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (1.0.0)
# Requirement already satisfied: tomli==2.0.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2.0.1)
# Collecting pytest-xdist==1.34.0
#   Downloading pytest_xdist-1.34.0-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: six==1.16.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (1.16.0)
# Collecting platformdirs==4.2.0
#   Downloading platformdirs-4.2.0-py3-none-any.whl (17 kB)
# Collecting python-dotenv==0.16.0
#   Downloading python_dotenv-0.16.0-py2.py3-none-any.whl (18 kB)
# Collecting black==24.1.1
#   Downloading black-24.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 65.4 MB/s eta 0:00:00
# Requirement already satisfied: pluggy==1.4.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (1.4.0)
# Requirement already satisfied: toolz==0.12.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.12.1)
# Collecting eth-abi==5.0.0
#   Downloading eth_abi-5.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: eth-hash[pycryptodome]==0.6.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.6.0)
# Requirement already satisfied: referencing==0.33.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.33.0)
# Collecting eth-keys==0.5.0
#   Using cached eth_keys-0.5.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: cytoolz==0.12.3 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.12.3)
# Requirement already satisfied: asttokens==2.4.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2.4.1)
# Requirement already satisfied: typing-extensions==4.9.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (4.9.0)
# Requirement already satisfied: requests==2.31.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (2.31.0)
# Requirement already satisfied: zipp==3.17.0 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (3.17.0)
# Requirement already satisfied: psutil==5.9.8 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (5.9.8)
# Collecting py-solc-ast==1.2.10
#   Downloading py_solc_ast-1.2.10-py3-none-any.whl (10.0 kB)
# Collecting execnet==2.0.2
#   Downloading execnet-2.0.2-py3-none-any.whl (37 kB)
# Collecting vyper==0.3.10
#   Downloading vyper-0.3.10-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.3/262.3 kB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: yarl==1.9.4 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (1.9.4)
# Requirement already satisfied: frozenlist==1.4.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (1.4.1)
# Requirement already satisfied: aiosignal==1.3.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (1.3.1)
# Requirement already satisfied: dataclassy==0.11.1 in /home/ubuntu/app/version-2-geospatial-pipelines/geospatial-pipelines/packages/flyte/.venv/lib/python3.10/site-packages (from eth-brownie) (0.11.1)
# Building wheels for collected packages: pygments-lexer-solidity
#   Building wheel for pygments-lexer-solidity (setup.py) ... done
#   Created wheel for pygments-lexer-solidity: filename=pygments_lexer_solidity-0.7.0-py3-none-any.whl size=7295 sha256=4e9f978ee142ffcd24061c58c3f13946f818da9b87dca488f4fed337df9f4410
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/ab/2d/d2/4203f3171dbe5a2c79e73c10f0420a8d84a92dafe429640eb2
# Successfully built pygments-lexer-solidity
# Installing collected packages: python-dotenv, pygments, py-solc-ast, py, platformdirs, multidict, lazy-object-proxy, hypothesis, execnet, certifi, cbor2, vyper, pytest, pygments-lexer-solidity, black, vvm, rlp, pytest-forked, py-solc-x, eth-keys, eth-abi, pytest-xdist, eth-event, web3, eth-brownie
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.0.1
#     Uninstalling python-dotenv-1.0.1:
#       Successfully uninstalled python-dotenv-1.0.1
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.15.0
#     Uninstalling Pygments-2.15.0:
#       Successfully uninstalled Pygments-2.15.0
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.1.0
#     Uninstalling platformdirs-4.1.0:
#       Successfully uninstalled platformdirs-4.1.0
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.0.4
#     Uninstalling multidict-6.0.4:
#       Successfully uninstalled multidict-6.0.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.4.4
#     Uninstalling pytest-7.4.4:
#       Successfully uninstalled pytest-7.4.4
#   Attempting uninstall: black
#     Found existing installation: black 22.12.0
#     Uninstalling black-22.12.0:
#       Successfully uninstalled black-22.12.0
#   Attempting uninstall: rlp
#     Found existing installation: rlp 3.0.0
#     Uninstalling rlp-3.0.0:
#       Successfully uninstalled rlp-3.0.0
#   Attempting uninstall: eth-keys
#     Found existing installation: eth-keys 0.4.0
#     Uninstalling eth-keys-0.4.0:
#       Successfully uninstalled eth-keys-0.4.0
#   Attempting uninstall: eth-abi
#     Found existing installation: eth-abi 4.2.1
#     Uninstalling eth-abi-4.2.1:
#       Successfully uninstalled eth-abi-4.2.1
#   Attempting uninstall: web3
#     Found existing installation: web3 6.15.1
#     Uninstalling web3-6.15.1:
#       Successfully uninstalled web3-6.15.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydantic-settings 2.1.0 requires python-dotenv>=0.21.0, but you have python-dotenv 0.16.0 which is incompatible.
# py-evm 0.7.0a4 requires eth-keys<0.5.0,>=0.4.0, but you have eth-keys 0.5.0 which is incompatible.
# py-evm 0.7.0a4 requires rlp<4,>=3, but you have rlp 4.0.0 which is incompatible.
# nerfstudio 1.0.1 requires protobuf!=3.20.0,<=3.20.3, but you have protobuf 4.25.2 which is incompatible.
# flytekit 1.8.1 requires urllib3<2.0.0,>=1.22, but you have urllib3 2.2.0 which is incompatible.
# eth-tester 0.9.1b2 requires eth-keys<0.5.0,>=0.4.0, but you have eth-keys 0.5.0 which is incompatible.
# eth-tester 0.9.1b2 requires rlp<4,>=3.0.0, but you have rlp 4.0.0 which is incompatible.
# eth-ape 0.7.7 requires eth-abi<5,>=4.2.1, but you have eth-abi 5.0.0 which is incompatible.
# bacalhau-sdk 1.1.1 requires black<23.0.0,>=22.12.0, but you have black 24.1.1 which is incompatible.
# bacalhau-sdk 1.1.1 requires certifi==2023.07.22, but you have certifi 2023.11.17 which is incompatible.
# bacalhau-sdk 1.1.1 requires pygments==2.15.0, but you have pygments 2.17.2 which is incompatible.
# Successfully installed black-24.1.1 cbor2-5.6.1 certifi-2023.11.17 eth-abi-5.0.0 eth-brownie-1.20.0 eth-event-1.2.5 eth-keys-0.5.0 execnet-2.0.2 hypothesis-6.27.3 lazy-object-proxy-1.10.0 multidict-6.0.5 platformdirs-4.2.0 py-1.11.0 py-solc-ast-1.2.10 py-solc-x-1.1.1 pygments-2.17.2 pygments-lexer-solidity-0.7.0 pytest-6.2.5 pytest-forked-1.6.0 pytest-xdist-1.34.0 python-dotenv-0.16.0 rlp-4.0.0 vvm-0.1.0 vyper-0.3.10 web3-6.15.0
# WARNING: There was an error checking the latest version of pip.

# %%
## first setting up the contracts folder from @geospatial-pipeline/web3 and then compiling the packages

from brownie import accounts
from subprocess import check_call


## compiling the contracts
